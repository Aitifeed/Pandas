# %%
import pandas as pd
import sqlite3

# %%
try:
  connect = sqlite3.connect('data/checking-logs.sqlite')
  print('OK. Connected to sqlite')

except sqlite3.Error as error:
  print('Error with connection:', error)
# Out:
# OK. Connected to sqlite

# %%
query = '''
SELECT *
FROM checker
WHERE uid LIKE 'user_%'
'''
checker = pd.io.sql.read_sql(query, connect, parse_dates=['datetime'])
checker['timestamp'] = checker['timestamp'].astype('datetime64[us]')
checker
# Out:
#       index    status  success                  timestamp  numTrials  \
# 0         7     ready        0 2020-04-17 05:19:02.744528          1
# 1         8  checking        0 2020-04-17 05:22:35.249331          2
# 2         9     ready        1 2020-04-17 05:22:45.549397          2
# 3        10  checking        1 2020-04-17 05:34:14.691200          3
# 4        11     ready        1 2020-04-17 05:34:24.422370          3
# ...     ...       ...      ...                        ...        ...
# 3202   3397     ready        0 2020-05-21 20:19:06.872761          7
# 3203   3398  checking        0 2020-05-21 20:22:41.785725          8
# 3204   3399     ready        0 2020-05-21 20:22:41.877806          8
# 3205   3400  checking        0 2020-05-21 20:37:00.129678          9
# 3206   3401     ready        0 2020-05-21 20:37:00.290491          9
#
#        labname     uid
# 0     project1  user_4
# 1     project1  user_4
# 2     project1  user_4
# 3     project1  user_4
# 4     project1  user_4
# ...        ...     ...
# 3202   laba06s  user_1
# 3203   laba06s  user_1
# 3204   laba06s  user_1
# 3205   laba06s  user_1
# 3206   laba06s  user_1
#
# [3207 rows x 7 columns]

# %%
##night is from 0:00:00 to 03:59:59, morning is from 04:00:00 to 09:59:59, afternoon
##is from 10:00:00 to 16:59:59, evening is from 17:00:00 to 23:59:59

# %%
checker['hh.mm'] = checker['timestamp'].dt.strftime('%H.%M')
checker['hh.mm'] = checker['hh.mm'].astype('float')
checker['timestamp'] = checker['timestamp'].dt.date
checker
# Out:
#       index    status  success   timestamp  numTrials   labname     uid  \
# 0         7     ready        0  2020-04-17          1  project1  user_4
# 1         8  checking        0  2020-04-17          2  project1  user_4
# 2         9     ready        1  2020-04-17          2  project1  user_4
# 3        10  checking        1  2020-04-17          3  project1  user_4
# 4        11     ready        1  2020-04-17          3  project1  user_4
# ...     ...       ...      ...         ...        ...       ...     ...
# 3202   3397     ready        0  2020-05-21          7   laba06s  user_1
# 3203   3398  checking        0  2020-05-21          8   laba06s  user_1
# 3204   3399     ready        0  2020-05-21          8   laba06s  user_1
# 3205   3400  checking        0  2020-05-21          9   laba06s  user_1
# 3206   3401     ready        0  2020-05-21          9   laba06s  user_1
#
#       hh.mm  daytime
# 0      5.19  morning
# 1      5.22  morning
# 2      5.22  morning
# 3      5.34  morning
# 4      5.34  morning
# ...     ...      ...
# 3202  20.19  evening
# 3203  20.22  evening
# 3204  20.22  evening
# 3205  20.37  evening
# 3206  20.37  evening
#
# [3207 rows x 9 columns]

# %%
bins = [0, 3.59, 9.59, 16.59, 23.59]
labels = ['night','morning','afternoon','evening']
checker['daytime']=pd.cut(checker['hh.mm'],bins = bins,labels = labels)
checker
# Out:
#       index    status  success   timestamp  numTrials   labname     uid  \
# 0         7     ready        0  2020-04-17          1  project1  user_4
# 1         8  checking        0  2020-04-17          2  project1  user_4
# 2         9     ready        1  2020-04-17          2  project1  user_4
# 3        10  checking        1  2020-04-17          3  project1  user_4
# 4        11     ready        1  2020-04-17          3  project1  user_4
# ...     ...       ...      ...         ...        ...       ...     ...
# 3202   3397     ready        0  2020-05-21          7   laba06s  user_1
# 3203   3398  checking        0  2020-05-21          8   laba06s  user_1
# 3204   3399     ready        0  2020-05-21          8   laba06s  user_1
# 3205   3400  checking        0  2020-05-21          9   laba06s  user_1
# 3206   3401     ready        0  2020-05-21          9   laba06s  user_1
#
#       hh.mm  daytime
# 0      5.19  morning
# 1      5.22  morning
# 2      5.22  morning
# 3      5.34  morning
# 4      5.34  morning
# ...     ...      ...
# 3202  20.19  evening
# 3203  20.22  evening
# 3204  20.22  evening
# 3205  20.37  evening
# 3206  20.37  evening
#
# [3207 rows x 9 columns]

# %%
connect.close()
